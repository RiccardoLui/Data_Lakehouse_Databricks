# %% [markdown]
# Run the gold layer notebooks for the pipeline

# %%
notebooks = [
    "./dim_customers",
    "./dim_product",
    "./fact_sales"
]

for nb in notebooks:
    print(f"Running {nb}")
    dbutils.notebook.run(nb, timeout_seconds=0)
