# %% [markdown]
# # Gold sales fact
#
# Production notebook with the post-write preview query removed.

# %%
spark.sql("""
CREATE OR REPLACE TABLE data_lakehouse_databricks.gold.gold_fact_sales
AS
SELECT
    order_number,
    product_key,
    customer_id,
    order_date,
    ship_date,
    due_date,
    sales_amount,
    quantity,
    price
FROM data_lakehouse_databricks.silver.silver_sales_details
""")
