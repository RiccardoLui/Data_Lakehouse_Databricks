# %% [markdown]
# Run the silver notebooks for the pipeline

# %%
notebooks = [
    "./01_silver_crm_customer",
    "./02_silver_crm_product",
    "./03_silver_crm_sales",
    "./04_silver_erp_customer_demographics",
    "./05_silver_erp_customer_location",
    "./06_silver_erp_product_category"
    #"./07_silver_diagnostics",
]

for nb in notebooks:
    print(f"Running {nb}")
    dbutils.notebook.run(nb, timeout_seconds=0)
